# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = np.load('/home/yuping/frank/image.npy')

# %%
im.shape
# Out:
# (4, 8192, 8192)

# %%
im[0].max()
# Out:
# 0.01666284

# %%
im[1].max()
# Out:
# 0.008194839

# %%
im[2].max()
# Out:
# 0.00035268744

# %%
im[3].max()
# Out:
# -0.0

# %%
im[0].std()
# Out:
# 2.38132e-05

# %%
# %matplotlib widget
plt.imshow(im[0], vmin=-1e-4, vmax=1e-4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
