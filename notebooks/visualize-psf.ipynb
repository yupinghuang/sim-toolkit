# %%
from plotpsf import get_psf_stats, get_psf_stats2, read_image_fits

# %%
import numpy as np

# %%
dist, radial_average, radial_std, radial_maxabs = get_psf_stats(
    '/safepool/data/AJ-15int-4000chan/15x60s-4000chan-briggs-0-75-psf.fits', 2)

# %%
from matplotlib import pyplot as plt
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_average, label='avgabs')
plt.plot(dist, radial_std, label='std')
plt.plot(dist, radial_maxabs, label='maxabs')
plt.xlabel('Offset(arcmin)')
plt.ylabel('PSF')
plt.yscale('log')
plt.grid()
plt.ylim([1e-6, 1])
plt.title('Briggs(0.75), 3.06asec x 3.05asec')
plt.legend()

matplotlib.rcParams.update({'font.size': 16})

# %%
matplotlib.rcParams.update({'font.size': 16})

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(18,5))
for ax in (ax1, ax2):
    ax.plot(dist, radial_average, label='avgabs')
    ax.plot(dist, radial_std, label='std')
    ax.plot(dist, radial_maxabs, label='maxabs')
    ax.set_yscale('log')
    ax.grid()
    ax.set_ylim([1e-6, 1])
    ax.legend()
    ax.set_xlabel('Offset(arcmin)')
ax1.set_ylabel('PSF')
ax1.set_xlim([0, 7.5])
plt.suptitle('AJ Briggs(0.75), 3.06asec x 3.05asec')
# Out:
# Text(0.5, 0.98, 'AJ Briggs(0.75), 3.06asec x 3.05asec')

# %%
dist1, radial_average1, radial_std1, radial_maxabs1 = get_psf_stats(
    '/safepool/data/AJ-15int-4000chan/15x60s-4000chan-briggs-0-9-psf.fits', 2)

# %%
dist2, radial_average2, radial_std2, radial_maxabs2 = get_psf_stats(
    '/safepool/data/AJ-15int-4000chan/15x60s-4000chan-briggs0-psf.fits', 1)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(18,5))
for ax in (ax1, ax2):
    ax.plot(dist3, radial_average3, label='avgabs')
    ax.plot(dist3, radial_std3, label='std')
    ax.plot(dist3, radial_maxabs3, label='maxabs')
    ax.set_yscale('log')
    ax.grid()
    ax.set_ylim([1e-6, 1])
    ax.legend()
    ax.set_xlabel('Offset(arcmin)')
ax1.set_ylabel('PSF')
ax1.set_xlim([0, 7.5])
plt.suptitle('AI Briggs(0.9), 3.29asec x 3.26asec')
# Out:
# Text(0.5, 0.98, 'AI Briggs(0.9), 3.29asec x 3.26asec')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(18,5))
for ax in (ax1, ax2):
    ax.plot(dist4, radial_average4, label='avgabs')
    ax.plot(dist4, radial_std4, label='std')
    ax.plot(dist4, radial_maxabs4, label='maxabs')
    ax.set_yscale('log')
    ax.grid()
    ax.set_ylim([1e-6, 1])
    ax.legend()
    ax.set_xlabel('Offset(arcmin)')
ax1.set_ylabel('PSF')
ax1.set_xlim([0, 7.5])
plt.suptitle('AJ Briggs(0.9) 5 bands, 3.45asec x 3.39asec')
# Out:
# Text(0.5, 0.98, 'AJ Briggs(0.9) 5 bands, 3.45asec x 3.39asec')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(18,5))
for ax in (ax1, ax2):
    ax.plot(dist1, radial_average1, label='avgabs')
    ax.plot(dist1, radial_std1, label='std')
    ax.plot(dist1, radial_maxabs1, label='maxabs')
    ax.set_yscale('log')
    ax.grid()
    ax.set_ylim([1e-6, 1])
    ax.legend()
    ax.set_xlabel('Offset(arcmin)')
ax1.set_ylabel('PSF')
ax1.set_xlim([0, 7.5])
plt.suptitle('AJ Briggs(0.9), 3.31asec x 3.27asec')
# Out:
# Text(0.5, 0.98, 'AJ Briggs(0.9), 3.31asec x 3.27asec')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(18,5))
for ax in (ax1, ax2):
    ax.plot(dist2, radial_average2, label='avgabs')
    ax.plot(dist2, radial_std2, label='std')
    ax.plot(dist2, radial_maxabs2, label='maxabs')
    ax.set_yscale('log')
    ax.grid()
    ax.set_ylim([1e-6, 1])
    ax.legend()
    ax.set_xlabel('Offset(arcmin)')
ax1.set_ylabel('PSF')
ax1.set_xlim([0, 7.5])
plt.suptitle('AJ Briggs(0), 2.0asec x 1.9asec')
# Out:
# Text(0.5, 0.98, 'AJ Briggs(0), 2.0asec x 1.9asec')

# %%
# major=3.29'', minor=3.26''
dist3, radial_average3, radial_std3, radial_maxabs3 = get_psf_stats(
    '/fastpool/data/AI-15int-4000chan/15x60s-4000chan-briggs-09-psf.fits', 2)

# %%
# major=3.45'', minor=3.39''
dist4, radial_average4, radial_std4, radial_maxabs4 = get_psf_stats(
    '/safepool/data/AJ-15int-4000chan/15x60s-4000chan-briggs-09-mfs-MFS-psf.fits', 2)

# %%
plt.figure(figsize=(8,8))
plt.plot(dist3*60, radial_average3, label='avgabs')
plt.xlabel('Offset(arcsec)')
plt.ylabel('PSF')
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.ylim([1e-6, 1])
#plt.title('AI Briggs(0.9), 3.29asec x 3.26asec')
plt.savefig('/home/yuping/AI-avg.png')

# %%
dist9, average9, std9, maxabs9, avg9 = get_psf_stats2(
    '/fastpool/data/W-15int-8000chan/15x60s-8000chan-natural-psf.fits', 2)

# %%
plt.figure(figsize=(8,8))
plt.plot(dist9*60, average9, label='avg')
plt.plot(dist9*60, std9, label='std')
plt.plot(dist9*60, maxabs9, label='max')
plt.xlabel('Offset(arcsec)')
plt.ylabel('PSF Amp')
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.legend()
plt.title('configuration W natural weight, 3.49asec x 3.42asec')
# Out:
# Text(0.5, 1.0, 'configuration W natural weight, 3.49asec x 3.42asec')

# %%
dist10, average10, std10, maxabs10, avg10 = get_psf_stats2(
    '/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-psf.fits', 2)

# %%
plt.figure(figsize=(8,8))
plt.plot(dist10*60, average10, label='avgabs')
plt.plot(dist10*60, np.abs(avg10), label='avg')
plt.plot(dist10*60, std10, label='std')
plt.plot(dist10*60, maxabs10, label='max')
plt.xlabel('Offset(arcsec)')
plt.ylabel('PSF Amp')
plt.yscale('log')
plt.xscale('log')
plt.grid()
plt.legend()
plt.title('configuration W briggs 0.9 weight')
# Out:
# Text(0.5, 1.0, 'configuration W briggs 0.9 weight')

# %%
from matplotlib.ticker import MultipleLocator
plt.figure(figsize=(4.4,4))
plt.plot(dist10*60, avg10)
plt.plot(-dist10*60, avg10, color='C0')
matplotlib.rcParams.update({'font.size': 12})
xx = np.linspace(-20, 20, 400)
sigma =3.1/2.355
gaus = np.exp(-((xx)**2 / (2.0 * sigma**2)))
plt.plot(xx, gaus, color='gray', linestyle='dashed')
plt.xlabel('distance [arcsec]', fontsize=15, fontname='DejaVu Sans')
plt.ylabel('PSF', fontsize=15, fontname='DejaVu Sans')
plt.text(-19, 0.94, 'DSA-2000', fontsize=15, fontname='DejaVu Sans')
plt.text(-19, 0.86, 'Gaussian fit', fontsize=12, color='gray', fontname='DejaVu Sans')
plt.xlim([-20, 20])
plt.minorticks_on()
plt.tight_layout()
plt.savefig('linear.pdf')

# %%
avg10.min()
# Out:
# -0.0020638706628233194

# %%
from matplotlib.ticker import MultipleLocator
plt.figure(figsize=(4.4,4))
matplotlib.rcParams.update({'font.size': 12})
plt.plot(dist10*60, avg10)
plt.plot(-dist10*60, avg10, color='C0')
matplotlib.rcParams.update({'font.size': 12})
plt.xlabel('distance [arcsec]', fontsize=15, fontname='DejaVu Sans')
plt.ylabel('abs(PSF)', fontsize=15, fontname='DejaVu Sans')
plt.text(-180, 0.3, 'DSA-2000', fontsize=15, fontname='DejaVu Sans')
plt.yscale('log')
plt.ylim(1e-6, 1)
plt.xlim(-200, 200)
plt.grid(linestyle='dotted')
plt.tight_layout()
plt.minorticks_on()
plt.savefig('log_avg_trunc.pdf')

# %%
plt.figure(figsize=(4.4,4))
matplotlib.rcParams.update({'font.size': 12})
plt.plot(dist10*60, np.abs(avg10))
plt.plot(-dist10*60, np.abs(avg10), color='C0')
matplotlib.rcParams.update({'font.size': 12})
plt.xlabel('distance [arcsec]', fontsize=15, fontname='DejaVu Sans')
plt.ylabel('abs(PSF)', fontsize=15, fontname='DejaVu Sans')
plt.text(-180, 0.3, 'DSA-2000', fontsize=15, fontname='DejaVu Sans')
plt.yscale('log')
plt.grid(linestyle='dotted')
plt.tight_layout()
plt.ylim(1e-6, 1)
plt.xlim(-200, 200)
plt.minorticks_on()
plt.savefig('log_absavg.pdf')

# %%
from matplotlib.ticker import MultipleLocator
plt.figure(figsize=(4.4,4))
matplotlib.rcParams.update({'font.size': 12})
plt.plot(dist10*60, average10)
plt.plot(-dist10*60, average10, color='C0')
matplotlib.rcParams.update({'font.size': 12})
# plt.xlabel('distance [arcsec]', fontsize=15, fontname='DejaVu Sans')
plt.xlabel('distance [arcsec]', fontsize=15, fontname='DejaVu Sans')
plt.ylabel('abs(PSF)', fontsize=15, fontname='DejaVu Sans')
plt.text(-180, 0.3, 'DSA-2000', fontsize=15, fontname='DejaVu Sans')
# plt.text(-19, 0.94, 'DSA-2000', fontsize=15, fontname='DejaVu Sans')
plt.yscale('log')
plt.xlim(-200, 200)
plt.ylim([1e-6, 1])
plt.minorticks_on()
plt.grid(linestyle='dotted')
plt.tight_layout()
plt.savefig('log_avgabs.pdf')

# %%
avg10.shape
# Out:
# (14399,)

# %%
np.savetxt('azimuthal_psf_stats_fullband_briggs_0_9_W.csv', np.array((dist10, average10, avg10)).T, delimiter=',', header='offset_amin, avg_abs, avg')

# %%
from plotpsf import read_image_fits

# %%
im, header = read_image_fits('/fastpool/data/W-15int-8000chan/15x60s-8000chan-natural-psf.fits')
print(np.sum(im))
print(np.abs(im).min())
im = None
# Out:
# 0.90400183
# 1.0969272e-16

# %%
0.9/(32000*32000)
# Out:
# 8.789062500000001e-10

# %% [markdown]
# ## 20230117 looking at phase corruptions addition to rms

# %%
dist, radial_average, radial_std, radial_maxabs = get_psf_stats(
    '/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-2deg-err.fits', 2)

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_std, label='std')
plt.xlabel('Offset(arcmin)')
plt.ylabel('PSF')
plt.yscale('log')
plt.grid()
plt.ylim([1e-6, 1])
plt.legend()

matplotlib.rcParams.update({'font.size': 16})

# %%
dist_psf, radial_average_psf, radial_std_psf, radial_maxabs_psf = get_psf_stats(
    '/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-psf.fits', 2)

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_std, label='std')
plt.plot(dist_psf, radial_std_psf, label='std')
plt.xlabel('Offset(arcmin)')
plt.ylabel('PSF')
plt.yscale('log')
plt.grid()
plt.ylim([1e-6, 1])
plt.legend()

matplotlib.rcParams.update({'font.size': 16})

# %%
(radial_std - radial_std_psf).min()
# Out:
# -5.445629358291626e-05

# %%
psf, _ = read_image_fits('/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-psf.fits')
image, _ = read_image_fits('/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-2deg-err.fits')

# %%
image_size = image.shape[0]
image_crop = image[image_size //2 - 16000: image_size // 2 + 16000, image_size //2 - 16000: image_size // 2 + 16000]

# %%
image_crop.argmax()
# Out:
# 512016000

# %%
image.max()
# Out:
# 0.9987453

# %%
psf.argmax()
# Out:
# 512016000

# %%
(radial_std * (1/image.max()) - radial_std_psf).min()
# Out:
# -1.3597179025727144e-07

# %%
(radial_std * (1/image.max()) - radial_std_psf).max()
# Out:
# 3.1426926868499683e-07

# %%
resid = image_crop - (psf * (image_crop.max()))

# %%
resid.max()
# Out:
# 4.815835e-06

# %%
resid.std()
# Out:
# 5.134758e-07

# %%
plt.hist(resid.flatten(), bins=50, range=(-2.5e-6, 2.5e-6));

# %%
resid.shape
# Out:
# (32000, 32000)

# %%
max_radius
# Out:
# 14399

# %%
len(circle_perimeter[0])
# Out:
# 81456

# %%
num_pix
# Out:
# 36000

# %%
_, header = read_image_fits('/fastpool/data/W-15int-8000chan/W-15x60s-8000chan-briggs09-psf.fits')
from skimage import draw
im = resid
extent_deg = 2.2
pixel_scale = abs(header['CDELT1'])
num_pix = abs(header['NAXIS1'])
max_radius = int(extent_deg/pixel_scale)
assert max_radius <= num_pix // 2
radial_avgabs=np.zeros(max_radius)
radial_std = np.zeros(max_radius)
radial_maxabs = np.zeros(max_radius)
for i in range(max_radius):
    circle_perimeter = draw.circle_perimeter(num_pix // 2, num_pix // 2, i)
    radial_avgabs[i] = np.mean(np.abs(im[circle_perimeter]))
    radial_std[i] = np.std(im[circle_perimeter])
    radial_maxabs[i] = np.abs(im[circle_perimeter]).max()
dist = np.linspace(0, max_radius*pixel_scale*60, num=max_radius)

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_std)
plt.xlabel('Offset(arcmin)')
plt.ylabel('Residuals')
plt.grid()

matplotlib.rcParams.update({'font.size': 16})
plt.xlim([0,20])
plt.ylim([0, 0.2e-6])
# Out:
# (0.0, 2e-07)

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_std)
plt.xlabel('Offset(arcmin)')
plt.ylabel('Residuals')
plt.grid()

matplotlib.rcParams.update({'font.size': 16})

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_maxabs)
plt.xlabel('Offset(arcmin)')
plt.ylabel('PSF')
plt.grid()

matplotlib.rcParams.update({'font.size': 16})

# %%
plt.figure(figsize=(8,5))
plt.plot(dist, radial_maxabs)
plt.xlabel('Offset(arcmin)')
plt.ylabel('Residual')
plt.grid()

matplotlib.rcParams.update({'font.size': 16})
plt.xlim([0,2])
# Out:
# (0.0, 2.0)
